# %% [markdown]
# <a href="https://colab.research.google.com/github/mhaletoki/MA22C025_2023_PL/blob/main/Assignments/Assignment_4/piecewisefunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the function f(x)
def f(x):
    if x < 0:
        return x * np.sin(x) * (x ** 2)
    else:
        return np.cos(x)

# %%
# Create an array of x values
x = np.linspace(-5, 5, 1000001)

# %%
# Calculate the corresponding y values using np.vectorize
y = np.vectorize(f)(x)

# %%
#Plot the function
plt.figure(figsize=(5,5))
plt.plot(x[x < 0], y[x < 0], label='f(x) for x < 0', color='blue')
plt.plot(x[x >= 0], y[x >= 0], label='f(x) for x >= 0', color='green')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) for -5 <= x <= 5')
plt.grid(True)
plt.legend()
plt.show()
